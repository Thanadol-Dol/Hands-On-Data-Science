# %% [markdown]
# # Exercise: Microchip Test

# %% [markdown]
# In this tutorial, you will be building a simple classifier that predicts of the microchip produced will be accepted based on the 2 values of the tests performed

# %% [markdown]
# ## Importing the libraries

# %% [markdown]
# ## Importing the dataset

# %% [markdown]
# # Visualising the dataset

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %% [markdown]
# ## Training models of your choice

# %% [markdown]
# Try multiple models and adjust some values. Which one perform the best?

# %% [markdown]
# ## Predicting the Test set results

# %% [markdown]
# ## Plotting the Confusion Matrix
