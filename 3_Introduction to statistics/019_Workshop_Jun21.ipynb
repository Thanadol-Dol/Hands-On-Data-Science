# %% [markdown]
# WorkShop 1

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('HR-Employee-Attrition.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
df.shape
# Out:
# (1470, 35)

# %%
female_selector = df["Gender"]=='Female'
df_female = df[female_selector]
print("The average age of female emplyees is "+str(df_female['Age'].mean()))
# Out:
# The average age of female emplyees is 37.32993197278912

# %%
df.groupby("JobRole")["DailyRate","TotalWorkingYears"].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                             DailyRate  TotalWorkingYears
# JobRole
# Healthcare Representative  854.251908          14.068702
# Human Resources            757.923077           8.173077
# Laboratory Technician      796.617761           7.656371
# Manager                    782.950980          24.549020
# Manufacturing Director     796.020690          12.786207
# Research Director          802.450000          21.400000
# Research Scientist         800.359589           7.715753
# Sales Executive            802.098160          11.101227
# Sales Representative       811.349398           4.674699

# %%
df.groupby(["JobLevel","Gender"])["MonthlyIncome"].agg(['mean','std'])
# Out:
#                          mean          std
# JobLevel Gender
# 1        Female   2780.487437   709.605053
#          Male     2790.633721   771.300650
# 2        Female   5435.327273  1266.690800
#          Male     5549.184713  1502.541186
# 3        Female   9962.702128  1892.555119
#          Male     9706.991935  1737.145905
# 4        Female  15431.372549  1701.573119
#          Male    15570.927273  1929.704985
# 5        Female  19129.916667   587.444052
#          Male    19224.844444   471.321930

# %% [markdown]
# # New Section

# %%
df.groupby(["JobRole"])["JobSatisfaction"].agg(['mean','std'])
# Out:
#                                mean       std
# JobRole
# Healthcare Representative  2.786260  1.109453
# Human Resources            2.557692  1.073997
# Laboratory Technician      2.691120  1.126306
# Manager                    2.705882  1.130918
# Manufacturing Director     2.682759  1.052137
# Research Director          2.700000  1.072085
# Research Scientist         2.773973  1.095260
# Sales Executive            2.754601  1.139997
# Sales Representative       2.734940  1.025104

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['YearsAtCompany'],df['MonthlyIncome'],c=df['JobSatisfaction'])
plt.colorbar()

# %%
df.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1448   41        No      Travel_Rarely        930                   Sales
# 357    21       Yes  Travel_Frequently        756                   Sales
# 795    37        No      Travel_Rarely        309                   Sales
# 1310   58        No  Travel_Frequently       1216  Research & Development
# 860    22       Yes  Travel_Frequently       1256  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 1448                 3          3     Life Sciences              1
# 357                  1          1  Technical Degree              1
# 795                 10          4     Life Sciences              1
# 1310                15          4     Life Sciences              1
# 860                  3          4     Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1448            2037  ...                         3            80
# 357              478  ...                         3            80
# 795             1105  ...                         3            80
# 1310            1837  ...                         2            80
# 860             1203  ...                         2            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1448                 1                 14                      5
# 357                  0                  3                      3
# 795                  3                  8                      5
# 1310                 0                 23                      3
# 860                  1                  1                      5
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1448               3               5                  4
# 357                3               3                  2
# 795                3               1                  0
# 1310               3               2                  2
# 860                3               0                  0
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 1448                        0                     4
# 357                         1                     2
# 795                         0                     0
# 1310                        2                     2
# 860                         0                     0
#
# [5 rows x 35 columns]

# %%
df.sample(5, random_state=2)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 721    50        No      Travel_Rarely        939  Research & Development
# 843    26        No      Travel_Rarely       1384  Research & Development
# 627    52        No  Travel_Frequently        890  Research & Development
# 1368   34        No  Travel_Frequently        735  Research & Development
# 305    36        No         Non-Travel       1105  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 721                 24          3  Life Sciences              1
# 843                  3          4        Medical              1
# 627                 25          4        Medical              1
# 1368                22          4          Other              1
# 305                 24          4  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 721             1005  ...                         4            80
# 843             1177  ...                         2            80
# 627              867  ...                         3            80
# 1368            1932  ...                         2            80
# 305              419  ...                         3            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 721                  1                 22                      2
# 843                  1                  8                      2
# 627                  0                 31                      3
# 1368                 0                 16                      3
# 305                  1                 11                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 721                3              12                 11
# 843                3               8                  7
# 627                3               9                  8
# 1368               3              15                 10
# 305                3               9                  8
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 721                         1                     5
# 843                         0                     7
# 627                         0                     0
# 1368                        6                    11
# 305                         0                     8
#
# [5 rows x 35 columns]

# %%
sample_1 = df.sample(100, random_state = 21)
sample_2 = df.sample(100, random_state = 43)
print("Mean of group1 is " +str(sample_1['MonthlyIncome'].mean()))
print("Mean of group2 is " +str(sample_2['MonthlyIncome'].mean()))
# Out:
# Mean of group1 is 6051.69
# Mean of group2 is 7137.58

# %%
plt.hist(df['MonthlyIncome'])
# Out:
# (array([365., 349., 290., 109., 110.,  56.,  52.,  18.,  54.,  67.]),
#  array([ 1009.,  2908.,  4807.,  6706.,  8605., 10504., 12403., 14302.,
#         16201., 18100., 19999.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Workshop 2

# %%
df = pd.read_csv('HR-Employee-Attrition.csv')

# %%
df.groupby("Gender")["MonthlyIncome"].agg(['mean','std'])
# Out:
#                mean          std
# Gender
# Female  6686.566327  4695.608507
# Male    6380.507937  4714.856577

# %%
df.groupby(["JobLevel","Gender"])["MonthlyIncome"].agg(['count','mean','std'])
# Out:
#                  count          mean          std
# JobLevel Gender
# 1        Female    199   2780.487437   709.605053
#          Male      344   2790.633721   771.300650
# 2        Female    220   5435.327273  1266.690800
#          Male      314   5549.184713  1502.541186
# 3        Female     94   9962.702128  1892.555119
#          Male      124   9706.991935  1737.145905
# 4        Female     51  15431.372549  1701.573119
#          Male       55  15570.927273  1929.704985
# 5        Female     24  19129.916667   587.444052
#          Male       45  19224.844444   471.321930

# %%
from scipy.stats import ttest_ind
female_rates = df[(df['Gender']== 'Female') ]['MonthlyIncome']
male_rates = df[(df['Gender']=='Male') ]['MonthlyIncome']
ttest_ind(female_rates,male_rates)
# Out:
# Ttest_indResult(statistic=1.2212617308870655, pvalue=0.22218303455087898)

# %%
features = ['TotalWorkingYears', 'JobLevel']
X = df[features]
Y = df['MonthlyIncome']
print(X.shape)
print(Y.shape)
# Out:
# (1470, 2)
# (1470,)

# %%
import seaborn as sns
sns.pairplot(X)

# %%
import seaborn as sns
sns.pairplot(pd.concat([X,Y],axis=1))

# %%
import statsmodels.api as sm 
X = sm.add_constant(X)
X.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#    const  TotalWorkingYears  JobLevel
# 0    1.0                  8         2
# 1    1.0                 10         2
# 2    1.0                  7         1
# 3    1.0                  8         1
# 4    1.0                  6         1

# %%
model = sm.OLS(Y,X).fit()
print(model.summary())
prediction = model.predict(X)
print("MAPE= " +str(100*np.mean(np.abs(((Y-prediction)/Y))))+"%")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          MonthlyIncome   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     7014.
# Date:                Tue, 21 Jun 2022   Prob (F-statistic):               0.00
# Time:                        08:54:32   Log-Likelihood:                -12785.
# No. Observations:                1470   AIC:                         2.558e+04
# Df Residuals:                    1467   BIC:                         2.559e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -1835.8617     80.019    -22.943      0.000   -1992.825   -1678.898
# TotalWorkingYears    46.0820      7.802      5.906      0.000      30.777      61.387
# JobLevel           3788.3785     54.843     69.077      0.000    3680.800    3895.957
# ==============================================================================
# Omnibus:                        7.910   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               10.099
# Skew:                          -0.047   Prob(JB):                      0.00641
# Kurtosis:                       3.395   Cond. No.                         32.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MAPE= 21.789386503343387%

# %%
one_hot_level = pd.get_dummies(df['JobLevel'],prefix='JobLevel_').iloc[:,:-1]
df[one_hot_level.columns] = one_hot_level
one_hot_level.head()
# Out:
#    JobLevel__1  JobLevel__2  JobLevel__3  JobLevel__4
# 0            0            1            0            0
# 1            0            1            0            0
# 2            1            0            0            0
# 3            1            0            0            0
# 4            1            0            0            0

# %%
import statsmodels.api as sm 
df.columns
features = ['TotalWorkingYears']+list(one_hot_level)
X = df[features]
X = sm.add_constant(X)
Y = df['MonthlyIncome']
model = sm.OLS(Y,X).fit()
print(model.summary())
prediction = model.predict(X)
print("MAPE= " +str(100*np.mean(np.abs(((Y-prediction)/Y))))+"%")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          MonthlyIncome   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.925
# Method:                 Least Squares   F-statistic:                     3648.
# Date:                Tue, 21 Jun 2022   Prob (F-statistic):               0.00
# Time:                        09:01:54   Log-Likelihood:                -12606.
# No. Observations:                1470   AIC:                         2.522e+04
# Df Residuals:                    1464   BIC:                         2.526e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               1.86e+04    243.592     76.361      0.000    1.81e+04    1.91e+04
# TotalWorkingYears    22.4050      7.132      3.141      0.002       8.415      36.395
# JobLevel__1       -1.595e+04    219.857    -72.529      0.000   -1.64e+04   -1.55e+04
# JobLevel__2       -1.333e+04    199.972    -66.670      0.000   -1.37e+04   -1.29e+04
# JobLevel__3       -9122.3481    194.870    -46.812      0.000   -9504.603   -8740.093
# JobLevel__4       -3667.7640    198.944    -18.436      0.000   -4058.010   -3277.518
# ==============================================================================
# Omnibus:                      104.067   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              228.728
# Skew:                           0.440   Prob(JB):                     2.15e-50
# Kurtosis:                       4.720   Cond. No.                         177.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# MAPE= 18.95048581091153%
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
import matplotlib.pyplot as plt
res = Y-prediction
plt.scatter(range(len(res)), res)
